// %%
using System;

namespace Question2
{
    class Program
    {
        static void Main(string[] args)
        {
            int iCountLetters = 0;
            Console.Write("Please enter a string to count: ");
            string strInput = Console.ReadLine();
            
            foreach (var chr in strInput)
            {
                if (char.IsLetter(chr))
                {
                    iCountLetters++;
                }
 
            }
            Console.WriteLine("There are {0} letters.", iCountLetters);
            
            Console.Write("Please enter the substring: ");
            string subString = Console.ReadLine();
            
            bool isSubstring = strInput.Contains(subString);
            Console.WriteLine("Substring exists: {0}", isSubstring);
            
            int iCountLetters2 = 0;
            Console.Write("Please enter the second string to count: ");
            string strInput2nd = Console.ReadLine();
                        
            foreach (var chr in strInput2nd)
            {
                if (char.IsLetter(chr))
                {
                    iCountLetters2++;
                }
 
            }
            Console.WriteLine("There are {0} letters.", iCountLetters2);
            
            int iCountLetters3 = 0;
            Console.Write("Please enter the third string to count: ");
            string strInput3rd = Console.ReadLine();
                        
            foreach (var chr in strInput3rd)
            {
                if (char.IsLetter(chr))
                {
                    iCountLetters3++;
                }
 
            }
            Console.WriteLine("There are {0} letters.", iCountLetters3);
            
            if (iCountLetters > iCountLetters2)
            {
                if (iCountLetters > iCountLetters3)
                {
                    Console.Write("The 1st String is the greatest among three. \n\n");
                }
                else
                {
                Console.Write("The 3rd String is the greatest among three. \n\n");
                }
            }
            else if (iCountLetters2 > iCountLetters3)
            Console.Write("The 2nd String is the greatest among three \n\n");
            else
            Console.Write("The 3rd String is the greatest among three \n\n");
        }
    }
}
// Out:
// (3,1): error CS7021: Cannot declare namespace in script code
